# %%
def knapsack(W, wt, val, n):
    # Create DP table
    dp = [[0] * (W + 1) for _ in range(n + 1)]

    # Build table dp[][] in bottom-up manner
    for i in range(1, n + 1):
        for w in range(1, W + 1):
            if wt[i - 1] <= w:
                dp[i][w] = max(val[i - 1] + dp[i - 1][w - wt[i - 1]],
                               dp[i - 1][w])
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][W]


# Driver Code
val = [60, 100, 120]  # values
wt = [10, 20, 30]     # weights
W = 50                # knapsack capacity
n = len(val)

print("Maximum value in Knapsack =", knapsack(W, wt, val, n))
# Out:
# Maximum value in Knapsack = 220

# %%
def knapsack(W, wt, val, n):
    dp = [[0] * (W+1) for _ in range(n+1)]

    for i in range(1, n+1):
        for w in range(1, W+1):
            if wt[i-1] <= w:
                dp[i][w]=max(val[i-1]+dp[i-1][w-wt[i-1]], dp[i-1][w])
            else:
                dp[i][w] = dp[i - 1][w]
    return dp[n][W]

val = [60, 100, 120]  # values
wt = [10, 20, 30]     # weights
W = 50                # knapsack capacity
n = len(val)

print("Maximum value in Knapsack =", knapsack(W, wt, val, n))
# Out:
# Maximum value in Knapsack = 220

# %%
def knapsack(W, wt, val, n):
    dp = [[0] * (W+1) for _ in range(n+1)]

    for i in range(1, n+1):
        for w in range(1, W+1):
            if wt[i-1]<=w:
                dp[i][w]=max(val[i-1]+dp[i-1][w-wt[i-1]],dp[i-1][w])
            else:
                dp[i][w]=dp[i-1][w]
    return dp[n][W]
val=[60,100,120]
wt=[10,20,30]
W=50
n=len(val)
print(knapsack(W,wt,val,n))
# Out:
# 220

# %%
def knapsack(W,wt,val,n):
    dp=[[0] * (W+1) for _ in range(n+1)]

    for i in range(1,n+1):
        for w in range(1,W+1):
            if wt[i-1]<=w:
                dp[i][w]=max(val[i-1]+dp[i-1][w-wt[i-1]],dp[i-1][w])
            else:
                dp[i][w]=dp[i-1][w]
    return dp[n][W]
    
def get_array(size):
    arr=[]
    for i in range(0,size):
        val=int(input(f"Enter the value for index {i}:"))
        arr.append(val)
    return arr

num_vals = int(input("Enter the number of values:"))
val = get_array(num_vals)
num_wt = int(input("Enter the number of weights:"))
wt = get_array(num_wt)
W = int(input("Knapsack Capacity:"))
print(f"Maximum value in Knapsack = {knapsack(W,wt,val,num_vals)}")
# Out:
# Enter the number of values: 3
# Enter the value for index 0: 60
# Enter the value for index 1: 100
# Enter the value for index 2: 120
# Enter the number of values: 3
# Enter the value for index 0: 10
# Enter the value for index 1: 20
# Enter the value for index 2: 30
# Kanpsack Capacity: 50
# 220
